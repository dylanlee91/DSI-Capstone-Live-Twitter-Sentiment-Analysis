# %%
#Base and Cleaning 
import sys
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
import pickle
from datetime import datetime
from datetime import date
import json
import requests
import emoji
import re
import string
import warnings
warnings.filterwarnings("ignore")

# %%
# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess

# %% [markdown]
# # Creating a combined dataset

# %%
df=pd.read_csv('../datasets/tweetstreamresults.csv')

# %%
print(df.shape)
df.head()
# Out:
# (309665, 6)
#               date            user  is_retweet  is_quote  \
# 0  4/10/2020 18:10    justincroser       False     False
# 1  4/10/2020 18:10      LFCYNWA125        True     False
# 2  4/10/2020 18:10  itstugenfinest        True     False
# 3  4/10/2020 18:10     guu_mendees        True     False
# 4  4/10/2020 18:10   justindivine5        True      True
#
#                                                 text  \
# 0  COME ON REDS!! 🔴🔴 Have to sleep for work but h...
# 1  RT @LFC: Jürgen Klopp provides detail on the s...
# 2  RT @SkySportsPL: 'I'm pretty sure he won't be ...
# 3  RT @ludovicofans: Now follow the news        L...
# 4  RT @AnfieldWatch: Jurgen Klopp: “It’s an inter...
#
#                                          quoted_text
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Liverpool face an anxious wait on how long the...

# %% [markdown]
# # Initial Processing

# %%
def add_mentions(text):
    mentionlist = re.findall(r'\B@\w+', text)
    if not mentionlist:
        mentionlist = np.NaN
    return mentionlist

def add_hashtags(text):
    hashtaglist = re.findall(r'\B(\#[a-zA-Z0-9]+\b)',text)
    if not hashtaglist:
        hashtaglist = np.NaN
    return hashtaglist

# %%
df['mentions'] = df['text'].apply(add_mentions)
df['hashtags'] = df['text'].apply(add_hashtags)

# %%
df['text'] = df['text'].str.lower()

# %%
df.head(10)
# Out:
#               date             user  is_retweet  is_quote  \
# 0  4/10/2020 18:10     justincroser       False     False
# 1  4/10/2020 18:10       LFCYNWA125        True     False
# 2  4/10/2020 18:10   itstugenfinest        True     False
# 3  4/10/2020 18:10      guu_mendees        True     False
# 4  4/10/2020 18:10    justindivine5        True      True
# 5  4/10/2020 18:10    GlazersOutSzn       False      True
# 6  4/10/2020 18:10      iSuperFrank       False      True
# 7  4/10/2020 18:10  Sir_EbubeEleazu        True     False
# 8  4/10/2020 18:10   avfcnewsgossip        True     False
# 9  4/10/2020 18:10           KRSNQ1       False      True
#
#                                                 text  \
# 0  come on reds!! 🔴🔴 have to sleep for work but h...
# 1  rt @lfc: jürgen klopp provides detail on the s...
# 2  rt @skysportspl: 'i'm pretty sure he won't be ...
# 3  rt @ludovicofans: now follow the news        l...
# 4  rt @anfieldwatch: jurgen klopp: “it’s an inter...
# 5                       @samuelluckhurst #glazersout
# 6                        المتعة مع جاكي بوي و المربع
# 7  rt @lfc: 📋 tonight's team news...   two change...
# 8  rt @villaandproud: with kick-off less than 30m...
# 9  lol we are conceding goals today pmds 😤😤😤 if w...
#
#                                          quoted_text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Liverpool face an anxious wait on how long the...
# 5  +/- 7 years  SEVEN YEARS AFTER SAF retired  wh...
# 6  🟣 𝗧 𝗘 𝗔 𝗠  𝗡 𝗘 𝗪 𝗦 🟣  @RBarkley8 makes his Ast...
# 7                                                NaN
# 8                                                NaN
# 9  Jürgen Klopp provides detail on the shoulder i...
#
#                       mentions                            hashtags
# 0                          NaN  [#AVLLIV, #LFC, #LFCFamily, #YNWA]
# 1       [@LFC, @Alissonbecker]                     [#LFC, #AVLLIV]
# 2               [@SkySportsPL]                                 NaN
# 3              [@ludovicofans]                                 NaN
# 4              [@AnfieldWatch]                                 NaN
# 5           [@samuelluckhurst]                       [#GlazersOut]
# 6                          NaN                                 NaN
# 7       [@LFC, @premierleague]                                 NaN
# 8  [@VillaAndProud, @LFC_LGBT]                                 NaN
# 9                          NaN                                 NaN

# %% [markdown]
# # Text Cleaning

# %%
def twitter_cleaner(text):
    text = re.sub(r'\B@\w+', 'username', text) # Replace usernames with placeholder
    text = re.sub(r'(rt)\b', '', text) # Remove retweets
    emoji_list = [c for c in text if c in emoji.UNICODE_EMOJI]
    text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)]) # Remove emojis
    text = re.sub(r'http\S+', '', text) # Remove urls
    text = re.sub(r'#*', '', text) # Remove hashtags
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) # Remove all punctuation
    text = re.sub('\w*\d\w*', '', text) # Remove words containing numbers
    text = re.sub('[^a-zA-Z 0-9]', '', text) # Remove all non letters or numbers
    return text

# %%
df['cleantext'] = df['text'].apply(twitter_cleaner)

# %%
df.head(10)
# Out:
#               date             user  is_retweet  is_quote  \
# 0  4/10/2020 18:10     justincroser       False     False
# 1  4/10/2020 18:10       LFCYNWA125        True     False
# 2  4/10/2020 18:10   itstugenfinest        True     False
# 3  4/10/2020 18:10      guu_mendees        True     False
# 4  4/10/2020 18:10    justindivine5        True      True
# 5  4/10/2020 18:10    GlazersOutSzn       False      True
# 6  4/10/2020 18:10      iSuperFrank       False      True
# 7  4/10/2020 18:10  Sir_EbubeEleazu        True     False
# 8  4/10/2020 18:10   avfcnewsgossip        True     False
# 9  4/10/2020 18:10           KRSNQ1       False      True
#
#                                                 text  \
# 0  come on reds!! 🔴🔴 have to sleep for work but h...
# 1  rt @lfc: jürgen klopp provides detail on the s...
# 2  rt @skysportspl: 'i'm pretty sure he won't be ...
# 3  rt @ludovicofans: now follow the news        l...
# 4  rt @anfieldwatch: jurgen klopp: “it’s an inter...
# 5                       @samuelluckhurst #glazersout
# 6                        المتعة مع جاكي بوي و المربع
# 7  rt @lfc: 📋 tonight's team news...   two change...
# 8  rt @villaandproud: with kick-off less than 30m...
# 9  lol we are conceding goals today pmds 😤😤😤 if w...
#
#                                          quoted_text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Liverpool face an anxious wait on how long the...
# 5  +/- 7 years  SEVEN YEARS AFTER SAF retired  wh...
# 6  🟣 𝗧 𝗘 𝗔 𝗠  𝗡 𝗘 𝗪 𝗦 🟣  @RBarkley8 makes his Ast...
# 7                                                NaN
# 8                                                NaN
# 9  Jürgen Klopp provides detail on the shoulder i...
#
#                       mentions                            hashtags  \
# 0                          NaN  [#AVLLIV, #LFC, #LFCFamily, #YNWA]
# 1       [@LFC, @Alissonbecker]                     [#LFC, #AVLLIV]
# 2               [@SkySportsPL]                                 NaN
# 3              [@ludovicofans]                                 NaN
# 4              [@AnfieldWatch]                                 NaN
# 5           [@samuelluckhurst]                       [#GlazersOut]
# 6                          NaN                                 NaN
# 7       [@LFC, @premierleague]                                 NaN
# 8  [@VillaAndProud, @LFC_LGBT]                                 NaN
# 9                          NaN                                 NaN
#
#                                            cleantext
# 0  come on reds have to sleep for work but hoping...
# 1  username jrgen klopp provides detail on the sh...
# 2  username im pretty sure he wont be ready after...
# 3  username now follow the news live live streami...
# 4  username jurgen klopp its an international bre...
# 5                                username glazersout
# 6
# 7  username tonights team news two changes from o...
# 8  username with kickoff less than  away we would...
# 9  lol we are conceding goals today pmds if we do...

# %% [markdown]
# # Language Processing for Non-english tweets

# %%
# Dealing with non english tweets
from langdetect import detect
def isenglish(text):
    try:
        if detect(text) == 'en':
            return 1
        else:
            return 0
    except:
        return 0

# %%
df['lang'] = df['cleantext'].apply(isenglish)

# %%
df.head(10)
# Out:
#               date             user  is_retweet  is_quote  \
# 0  4/10/2020 18:10     justincroser       False     False
# 1  4/10/2020 18:10       LFCYNWA125        True     False
# 2  4/10/2020 18:10   itstugenfinest        True     False
# 3  4/10/2020 18:10      guu_mendees        True     False
# 4  4/10/2020 18:10    justindivine5        True      True
# 5  4/10/2020 18:10    GlazersOutSzn       False      True
# 6  4/10/2020 18:10      iSuperFrank       False      True
# 7  4/10/2020 18:10  Sir_EbubeEleazu        True     False
# 8  4/10/2020 18:10   avfcnewsgossip        True     False
# 9  4/10/2020 18:10           KRSNQ1       False      True
#
#                                                 text  \
# 0  come on reds!! 🔴🔴 have to sleep for work but h...
# 1  rt @lfc: jürgen klopp provides detail on the s...
# 2  rt @skysportspl: 'i'm pretty sure he won't be ...
# 3  rt @ludovicofans: now follow the news        l...
# 4  rt @anfieldwatch: jurgen klopp: “it’s an inter...
# 5                       @samuelluckhurst #glazersout
# 6                        المتعة مع جاكي بوي و المربع
# 7  rt @lfc: 📋 tonight's team news...   two change...
# 8  rt @villaandproud: with kick-off less than 30m...
# 9  lol we are conceding goals today pmds 😤😤😤 if w...
#
#                                          quoted_text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Liverpool face an anxious wait on how long the...
# 5  +/- 7 years  SEVEN YEARS AFTER SAF retired  wh...
# 6  🟣 𝗧 𝗘 𝗔 𝗠  𝗡 𝗘 𝗪 𝗦 🟣  @RBarkley8 makes his Ast...
# 7                                                NaN
# 8                                                NaN
# 9  Jürgen Klopp provides detail on the shoulder i...
#
#                       mentions                            hashtags  \
# 0                          NaN  [#AVLLIV, #LFC, #LFCFamily, #YNWA]
# 1       [@LFC, @Alissonbecker]                     [#LFC, #AVLLIV]
# 2               [@SkySportsPL]                                 NaN
# 3              [@ludovicofans]                                 NaN
# 4              [@AnfieldWatch]                                 NaN
# 5           [@samuelluckhurst]                       [#GlazersOut]
# 6                          NaN                                 NaN
# 7       [@LFC, @premierleague]                                 NaN
# 8  [@VillaAndProud, @LFC_LGBT]                                 NaN
# 9                          NaN                                 NaN
#
#                                            cleantext  lang
# 0  come on reds have to sleep for work but hoping...     1
# 1  username jrgen klopp provides detail on the sh...     1
# 2  username im pretty sure he wont be ready after...     1
# 3  username now follow the news live live streami...     1
# 4  username jurgen klopp its an international bre...     1
# 5                                username glazersout     1
# 6                                                        0
# 7  username tonights team news two changes from o...     1
# 8  username with kickoff less than  away we would...     1
# 9  lol we are conceding goals today pmds if we do...     1

# %%
df['lang'].value_counts()
# Out:
# 1    207727
# 0    101938
# Name: lang, dtype: int64

# %%
df.to_csv('../datasets/avlliv_cleaned.csv', index_label=False)

# %% [markdown]
# # Processing for Twitter Specific

# %%
df = pd.read_csv('../datasets/avlliv_cleaned.csv')

# %%
# Using only the tweets identified as English
df = df.loc[df['lang'] == 1]

# %%
df.reset_index(inplace = True, drop = True)

# %%
with open('pickle/avlliv_playerlist.pickle', 'rb') as f:
    playerlist = pickle.load(f)

# %%
def clean_players(text, playerlist = playerlist):
    output=[]
    try:
        for name in playerlist:
            characters=['\\b']
            for letter in list(name.lower()):
                characters.append('([')
                characters.append(letter.upper())
                characters.append(letter.lower())
                characters.append(']+)')
            entry=''.join(characters)
            output.append(entry)
        for i,j in zip(output,playerlist):
            clean_text = re.sub(i, j, text)
    except TypeError:
        clean_text= ''
    return clean_text

# %%
df['cleantext'] = df['cleantext'].apply(lambda x: clean_players(x))

# %% [markdown]
# # Tokenizing and Lemmatizing

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
with open('pickle/avlliv.pickle', 'rb') as f:
    matchterms = pickle.load(f)
stop_words.extend(matchterms)

# %%
def tokenize_lemmatize(df=df, textcolumn='cleantext'):
    tweetlist = []
    for tweet in df[textcolumn].values.tolist():
        tweet = simple_preprocess(str(tweet), deacc=True)
        tweetlist.append(tweet)
    
    # Instantiate and build the bigram and trigram models
    bigram = gensim.models.Phrases(tweetlist, min_count=5, threshold=100) # higher threshold fewer phrases.
    trigram = gensim.models.Phrases(bigram[tweetlist], threshold=100)  
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    
    # Form bigrams and trigrams with the tweet content
    tweetlist = [[word for word in simple_preprocess(str(tweet)) if word not in stop_words] for tweet in tweetlist]
    tweetlist = [bigram_mod[tweet] for tweet in tweetlist]
    tweetlist = [trigram_mod[bigram_mod[tweet]] for tweet in tweetlist]
    
    output = []
    nlp = spacy.load('en_core_web_lg', disable=['parser', 'ner'])
    
    for word in tweetlist:
        fulltweet = nlp(" ".join(word)) 
        output.append([token.lemma_ for token in fulltweet])
        
    # Final pass to filter the tokens for stopwords
    output = [[word for word in simple_preprocess(str(tweet)) if word not in stop_words] for tweet in output]
    df['tokens'] = output
    return df

df = tokenize_lemmatize()

# %%
# Adjusting the time

# %%
df['datetime']=pd.to_datetime(df['date'],format='%d/%m/%Y %H:%M')

# %%
df['time'] = df['datetime'].dt.time

# %%
df.to_csv('../datasets/avlliv_cleaned_tokenized.csv', index_label=False)

# %%
df['tokens']
# Out:
# ['username', 'jurgen', 'klopp', 'pretty', 'sure', 'ready', 'see', 'week']

# %%
df
# Out:
#                    date             user  is_retweet  is_quote  \
# 0       4/10/2020 18:10     justincroser       False     False
# 1       4/10/2020 18:10       LFCYNWA125        True     False
# 2       4/10/2020 18:10   itstugenfinest        True     False
# 3       4/10/2020 18:10      guu_mendees        True     False
# 4       4/10/2020 18:10    justindivine5        True      True
# ...                 ...              ...         ...       ...
# 207722  4/10/2020 20:20  notbitterbetter       False     False
# 207723  4/10/2020 20:20        artDante1       False     False
# 207724  4/10/2020 20:20         jonesy73       False     False
# 207725  4/10/2020 20:20         ryanYNWA        True     False
# 207726  4/10/2020 20:20            A93ii        True     False
#
#                                                      text  \
# 0       come on reds!! 🔴🔴 have to sleep for work but h...
# 1       rt @lfc: jürgen klopp provides detail on the s...
# 2       rt @skysportspl: 'i'm pretty sure he won't be ...
# 3       rt @ludovicofans: now follow the news        l...
# 4       rt @anfieldwatch: jurgen klopp: “it’s an inter...
# ...                                                   ...
# 207722  villa were poor there  should’ve scored 10 or 11.
# 207723  good time to be alive...  manchester united lo...
# 207724  gutted that we couldn’t all be there together ...
# 207725  rt @elliothackney: everyone: last season was b...
# 207726  rt @avfcofficial: 90’ | 'we want eight!'  ...i...
#
#                                               quoted_text  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       Liverpool face an anxious wait on how long the...
# ...                                                   ...
# 207722                                                NaN
# 207723                                                NaN
# 207724                                                NaN
# 207725                                                NaN
# 207726                                                NaN
#
#                           mentions  \
# 0                              NaN
# 1       ['@LFC', '@Alissonbecker']
# 2                 ['@SkySportsPL']
# 3                ['@ludovicofans']
# 4                ['@AnfieldWatch']
# ...                            ...
# 207722                         NaN
# 207723                         NaN
# 207724                         NaN
# 207725          ['@ElliotHackney']
# 207726           ['@AVFCOfficial']
#
#                                           hashtags  \
# 0       ['#AVLLIV', '#LFC', '#LFCFamily', '#YNWA']
# 1                              ['#LFC', '#AVLLIV']
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 207722                                         NaN
# 207723                                 ['#AVLLFC']
# 207724                                         NaN
# 207725                                         NaN
# 207726                                 ['#AVLLIV']
#
#                                                 cleantext  lang  \
# 0       come on reds have to sleep for work but hoping...     1
# 1       username jrgen klopp provides detail on the sh...     1
# 2       username im pretty sure he wont be ready after...     1
# 3       username now follow the news live live streami...     1
# 4       username jurgen klopp its an international bre...     1
# ...                                                   ...   ...
# 207722         villa were poor there shouldve scored  or      1
# 207723  good time to be alive manchester united loses ...     1
# 207724  gutted that we couldnt all be there together t...     1
# 207725  username everyone last season was boring liver...     1
# 207726  username   we want eight is what the crowd wou...     1
#
#                                                    tokens            datetime  \
# 0       [come, red, sleep, work, hope, win, go, watch,... 2020-10-04 18:10:00
# 1       [username, detail, shoulder_injury, sideline, ... 2020-10-04 18:10:00
# 2       [username, pretty, sure, ready, set, week, sid... 2020-10-04 18:10:00
# 3       [username, follow, news, live, live, streaming... 2020-10-04 18:10:00
# 4       [username, jurgen, klopp, pretty, sure, ready,... 2020-10-04 18:10:00
# ...                                                   ...                 ...
# 207722                                      [poor, score] 2020-10-04 20:20:00
# 207723  [good, time, alive, manchester, united, lose, ... 2020-10-04 20:20:00
# 207724  [gutte, could, together, enjoy, tonight, trip,... 2020-10-04 20:20:00
# 207725  [username, everyone, last, season, bore, run, ... 2020-10-04 20:20:00
# 207726      [username, eight, crowd, would, singe, right] 2020-10-04 20:20:00
#
#             time
# 0       18:10:00
# 1       18:10:00
# 2       18:10:00
# 3       18:10:00
# 4       18:10:00
# ...          ...
# 207722  20:20:00
# 207723  20:20:00
# 207724  20:20:00
# 207725  20:20:00
# 207726  20:20:00
#
# [207727 rows x 13 columns]

# %%
terms = df[['datetime','time','tokens']].explode('tokens')

# %%
terms.to_csv('../datasets/avlliv_terms.csv', index_label = False)
