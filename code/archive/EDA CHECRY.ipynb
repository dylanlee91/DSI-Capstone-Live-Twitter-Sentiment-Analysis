# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
from datetime import datetime
from datetime import date

# %%
df1=pd.read_csv('../datasets/chelseapalacetweets.csv')
df2=pd.read_csv('../datasets/chelseapalacetweets2.csv')
df3=pd.read_csv('../datasets/chelseapalacetweets3.csv')
df4=pd.read_csv('../datasets/chelseapalacetweets4.csv')
df5=pd.read_csv('../datasets/chelseapalacetweets5.csv')
df6=pd.read_csv('../datasets/chelseapalacetweets6.csv')
df7=pd.read_csv('../datasets/chelseapalacetweets7.csv')

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7], axis=0, join='outer', ignore_index=True, verify_integrity=True)

# %%
df
# Out:
#               username                                               text  \
# 0          titomar_758  Chelsea vs Crystal palace. \n\n• Mendy clean s...
# 1         Kennyroja191  Wait, this same Crystal Palace flogged Man Utd...
# 2         John38466297  Seems like beating Crystal Palace at home this...
# 3           damyyllare  🏴󠁧󠁢󠁥󠁮󠁧󠁿 Ben Chilwell vs Crystal Palace\n\n90 m...
# 4        Younguzumaki1  I love how Havertz constantly roams around the...
# ...                ...                                                ...
# 14084  schoolBoyfrm5th  Ben Chilwell has lost possession (5) more time...
# 14085       Tamar__lee        Is this the crystal palace that beat Man U?
# 14086     I_am_Tangeni  Ano, TF is up with Palace? Can’t believe we go...
# 14087     Arsenal_LINY  It just keeps getting worst for Crystal Palace...
# 14088      Independent  GOAL! Jorginho adds a second following row wit...
#
#             tweetcreatedts         hashtags  \
# ...

# %%
df=df.loc[~df.duplicated()]

# %%
df
# Out:
#               username                                               text  \
# 0          titomar_758  Chelsea vs Crystal palace. \n\n• Mendy clean s...
# 1         Kennyroja191  Wait, this same Crystal Palace flogged Man Utd...
# 2         John38466297  Seems like beating Crystal Palace at home this...
# 3           damyyllare  🏴󠁧󠁢󠁥󠁮󠁧󠁿 Ben Chilwell vs Crystal Palace\n\n90 m...
# 4        Younguzumaki1  I love how Havertz constantly roams around the...
# ...                ...                                                ...
# 14084  schoolBoyfrm5th  Ben Chilwell has lost possession (5) more time...
# 14085       Tamar__lee        Is this the crystal palace that beat Man U?
# 14086     I_am_Tangeni  Ano, TF is up with Palace? Can’t believe we go...
# 14087     Arsenal_LINY  It just keeps getting worst for Crystal Palace...
# 14088      Independent  GOAL! Jorginho adds a second following row wit...
#
#             tweetcreatedts         hashtags  \
# ...

# %%
df.to_csv('../datasets/chelseapalacetweetscombined.csv',index=False)
